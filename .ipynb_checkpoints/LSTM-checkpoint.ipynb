# %% [markdown]
# 数据来源:
# http://archive.ics.uci.edu/ml/datasets/Individual+household+electric+power+consumption
#
# 数据信息:
#
# 1.date: 日期
#
# 2.time: 时间
#
# 3.global_active_power: 家庭全球每分钟平均有功功率（千瓦）
#
# 4.global_reactive_power: 家庭全球每分钟平均无功功率（千瓦）
#
# 5.voltage: 每分钟平均电压（伏特）
#
# 6.global_intensity: 家用全球每分钟平均电流强度（安培）
#
# 7.sub_metering_1: 1号电能分表（有功电能的瓦时）。它与厨房相对应，主要包括一台洗碗机、一台烤箱和一台微波炉（电热板不是电动的，而是燃气驱动的）。
#
# 8.sub_metering_2: 2号电能分表（有功电能的瓦时）。它相当于洗衣房，包括一台洗衣机、一台滚筒式干燥机、一台冰箱和一盏灯。
#
# 9.sub_metering_3:3号电能分表（有功电能的瓦时）。它相当于一台电热水器和一台空调

# %%
# 导入环境的包

import sys 
import numpy as np # linear algebra
from scipy.stats import randint
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv), data manipulation as in SQL
import matplotlib.pyplot as plt # this is used for the plot the graph 
import seaborn as sns # used for plot interactive graph. 
from sklearn.model_selection import train_test_split # to split the data into two parts
from sklearn.model_selection  import KFold # use for cross validation
from sklearn.preprocessing import StandardScaler # for normalization
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline # pipeline making
from sklearn.model_selection import cross_val_score
from sklearn.feature_selection import SelectFromModel
from sklearn import metrics # for the check the error and accuracy of the model
from sklearn.metrics import mean_squared_error,r2_score

## keras
import keras
from keras.layers import Dense, Flatten, RepeatVector
from keras.layers import Dense
from keras.models import Sequential
from keras.utils import to_categorical
from keras.optimizers import SGD 
from keras.callbacks import EarlyStopping
from keras.utils import np_utils
import itertools
from keras.layers import LSTM
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.layers import Dropout

# %%
#读入数据，注意数据位置
df = pd.read_csv('household_power_consumption.txt', sep=';', 
                 parse_dates={'dt' : ['Date', 'Time']}, infer_datetime_format=True, 
                 low_memory=False, na_values=['nan','?'], index_col='dt')

# %% [markdown]
#  ## 1) 请注意，数据包括“nan”和“？”一串。我在导入阶段（上图）将两者都转换为numpy nan，并对它们进行了相同的处理。
#
# ## 2)将两列“日期”和“时间”合并到“dt”
#
# ## 3) 将上面的数据转换为时间序列类型，将索引作为时间

# %%
#显示头部几行数据
df.head()
# Out:
#                      Global_active_power  Global_reactive_power  Voltage  \
# dt
# 2006-12-16 17:24:00                4.216                  0.418   234.84
# 2006-12-16 17:25:00                5.360                  0.436   233.63
# 2006-12-16 17:26:00                5.374                  0.498   233.29
# 2006-12-16 17:27:00                5.388                  0.502   233.74
# 2006-12-16 17:28:00                3.666                  0.528   235.68
#
#                      Global_intensity  Sub_metering_1  Sub_metering_2  \
# dt
# 2006-12-16 17:24:00              18.4             0.0             1.0
# 2006-12-16 17:25:00              23.0             0.0             1.0
# 2006-12-16 17:26:00              23.0             0.0             2.0
# 2006-12-16 17:27:00              23.0             0.0             1.0
# 2006-12-16 17:28:00              15.8             0.0             1.0
#
#                      Sub_metering_3
# dt
# 2006-12-16 17:24:00            17.0
# ...

# %%
#数据信息
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2075259 entries, 2006-12-16 17:24:00 to 2010-11-26 21:02:00
# Data columns (total 7 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Global_active_power    float64
#  1   Global_reactive_power  float64
#  2   Voltage                float64
#  3   Global_intensity       float64
#  4   Sub_metering_1         float64
#  5   Sub_metering_2         float64
#  6   Sub_metering_3         float64
# dtypes: float64(7)
# memory usage: 126.7 MB

# %%
#数据类型
df.dtypes
# Out:
# Global_active_power      float64
# Global_reactive_power    float64
# Voltage                  float64
# Global_intensity         float64
# Sub_metering_1           float64
# Sub_metering_2           float64
# Sub_metering_3           float64
# dtype: object

# %%
#数据形状
df.shape
# Out:
# (2075259, 7)

# %%
#数据的一些统计分析
df.describe()
# Out:
#        Global_active_power  Global_reactive_power       Voltage  \
# count         2.049280e+06           2.049280e+06  2.049280e+06
# mean          1.091615e+00           1.237145e-01  2.408399e+02
# std           1.057294e+00           1.127220e-01  3.239987e+00
# min           7.600000e-02           0.000000e+00  2.232000e+02
# 25%           3.080000e-01           4.800000e-02  2.389900e+02
# 50%           6.020000e-01           1.000000e-01  2.410100e+02
# 75%           1.528000e+00           1.940000e-01  2.428900e+02
# max           1.112200e+01           1.390000e+00  2.541500e+02
#
#        Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3
# count      2.049280e+06    2.049280e+06    2.049280e+06    2.049280e+06
# mean       4.627759e+00    1.121923e+00    1.298520e+00    6.458447e+00
# std        4.444396e+00    6.153031e+00    5.822026e+00    8.437154e+00
# min        2.000000e-01    0.000000e+00    0.000000e+00    0.000000e+00
# ...

# %%
#数据列
df.columns
# Out:
# Index(['Global_active_power', 'Global_reactive_power', 'Voltage',
#        'Global_intensity', 'Sub_metering_1', 'Sub_metering_2',
#        'Sub_metering_3'],
#       dtype='object')

# %% [markdown]
# ##处理缺失值“nan”

# %%
## 找到所有的列还有nan缺失值:

droping_list_all=[]
for j in range(0,7):
    if not df.iloc[:, j].notnull().all():
        droping_list_all.append(j)        
        #print(df.iloc[:,j].unique())
droping_list_all
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
# 去掉缺失值

for j in range(0,7):        
        df.iloc[:,j]=df.iloc[:,j].fillna(df.iloc[:,j].mean())

# %%
# 再做一次精神检查，确保没有nan
df.isnull().sum()
# Out:
# Global_active_power      0
# Global_reactive_power    0
# Voltage                  0
# Global_intensity         0
# Sub_metering_1           0
# Sub_metering_2           0
# Sub_metering_3           0
# dtype: int64

# %% [markdown]
# # 数据可视化分析

# %% [markdown]
# ## 下面对一天中的数据进行了重采样，并显示了全局有效功率的总和和平均值。可以看出，重采样数据集的平均值和总和具有相似的结构。

# %%
df.Global_active_power.resample('D').sum().plot(title='Global_active_power resampled over day for sum') 
#df.Global_active_power.resample('D').mean().plot(title='Global_active_power resampled over day', color='red') 
plt.tight_layout()
plt.show()   

df.Global_active_power.resample('D').mean().plot(title='Global_active_power resampled over day for mean', color='red') 
plt.tight_layout()
plt.show()

# %%
### 下面展示了一天内重新采样的“全球_强度”的平均值和标准差
r = df.Global_intensity.resample('D').agg(['mean', 'std'])
r.plot(subplots = True, title='Global_intensity resampled over day')
plt.show()

# %%
### 下面展示了一天内重新采样的“全球无功功率”的平均值和标准值
r2 = df.Global_reactive_power.resample('D').agg(['mean', 'std'])
r2.plot(subplots = True, title='Global_reactive_power resampled over day', color='red')
plt.show()

# %%
### 当月重新采样的“全球有功功率”总和
df['Global_active_power'].resample('M').mean().plot(kind='bar')
plt.xticks(rotation=60)
plt.ylabel('Global_active_power')
plt.title('Global_active_power per month (averaged over month)')
plt.show()

# %%
## 四分之一季度内“全球活跃电力”的平均值
df['Global_active_power'].resample('Q').mean().plot(kind='bar')
plt.xticks(rotation=60)
plt.ylabel('Global_active_power')
plt.title('Global_active_power per quarter (averaged over quarter)')
plt.show()

# %% [markdown]
# ### 从以上两个图中值得注意的是，在更大的时间间隔内进行重采样，会像我们预期的那样减少系统的周期性。这对于机器学习特征工程非常重要。

# %%
## 一个月内重新采样的“电压”平均值
df['Voltage'].resample('M').mean().plot(kind='bar', color='red')
plt.xticks(rotation=60)
plt.ylabel('Voltage')
plt.title('Voltage per quarter (summed over quarter)')
plt.show()

# %%
df['Sub_metering_1'].resample('M').mean().plot(kind='bar', color='brown')
plt.xticks(rotation=60)
plt.ylabel('Sub_metering_1')
plt.title('Sub_metering_1 per quarter (summed over quarter)')
plt.show()

# %% [markdown]
#  ## * 从上面的曲线图可以看出，与其他特征相比，Voltage在一个月内的平均值几乎是恒定的。这在特征选择中同样重要。

# %%
# 下面比较了一天中不同特征的平均值
# 绘制指定的列
cols = [0, 1, 2, 3, 5, 6]
i = 1
groups=cols
values = df.resample('D').mean().values
# 绘制每一列
plt.figure(figsize=(15, 10))
for group in groups:
	plt.subplot(len(cols), 1, i)
	plt.plot(values[:, group])
	plt.title(df.columns[group], y=0.75, loc='right')
	i += 1
plt.show()

# %%
## 一周内的重采样和计算平均值
df.Global_reactive_power.resample('W').mean().plot(color='y', legend=True)
df.Global_active_power.resample('W').mean().plot(color='r', legend=True)
df.Sub_metering_1.resample('W').mean().plot(color='b', legend=True)
df.Global_intensity.resample('W').mean().plot(color='g', legend=True)
plt.show()

# %%
# 下面展示了一个月内重新取样的不同特征的平均值的历史图
df.Global_active_power.resample('M').mean().plot(kind='hist', color='r', legend=True )
df.Global_reactive_power.resample('M').mean().plot(kind='hist',color='b', legend=True)
#df.Voltage.resample('M').sum().plot(kind='hist',color='g', legend=True)
df.Global_intensity.resample('M').mean().plot(kind='hist', color='g', legend=True)
df.Sub_metering_1.resample('M').mean().plot(kind='hist', color='y', legend=True)
plt.show()

# %%
## 'Global_intensity', 'Global_active_power'之间的相关性
data_returns = df.pct_change()
sns.jointplot(x='Global_intensity', y='Global_active_power', data=data_returns)  

plt.show()

# %% [markdown]
# ### * 从以上两个图中可以看出，“Global_intensity”和“Global_active_power”是相关的。但“Voltage”、“Global_active_power”之间的相关性较小。这是机器学习的重要观察。

# %%
##  'Voltage' and  'Global_active_power'之间的相关性
sns.jointplot(x='Voltage', y='Global_active_power', data=data_returns)  
plt.show()

# %% [markdown]
# # 特征间的相关性--热力图

# %%
# 各特征间的相关性，颜色越深，相关性越大
plt.matshow(df.corr(method='spearman'),vmax=1,vmin=-1,cmap='PRGn')
plt.title('without resampling', size=15)
plt.colorbar()
plt.show()

# %%
# 几个月内重新采样的特征平均值的相关性

plt.matshow(df.resample('M').mean().corr(method='spearman'),vmax=1,vmin=-1,cmap='PRGn')
plt.title('resampled over month', size=15)
plt.colorbar()
plt.margins(0.02)
plt.matshow(df.resample('A').mean().corr(method='spearman'),vmax=1,vmin=-1,cmap='PRGn')
plt.title('resampled over year', size=15)
plt.colorbar()
plt.show()

# %% [markdown]
# ## * 从上面可以看出，使用重采样技术可以改变特征之间的相关性。这对于特征工程非常重要。

# %% [markdown]
# ### * ##机器学习：CNN-LSTM数据准备和特征工程
#
# ### * 在给定当前时间（t）的预测到Global_Active_Power测量和其他时间步骤中的其他功能，搭建监督学习问题算法。

# %%
#将序列转为监督学习序列数据
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	dff = pd.DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(dff.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(dff.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = pd.concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# %% [markdown]
# ### * 为了减少计算时间，并且还可以获得测试模型的快速结果。一个可以将数据重新覆盖到小时内（原始数据以分钟为单位）。这将使数据的大小从2075259降至34589，但保持如上所述的整体数据库

# %%
## 多小时重新采样数据
df_resample = df.resample('h').mean() 
df_resample.shape
# Out:
# (34589, 7)

# %%
## * Note: 归一化数据范围为0-1.

values = df_resample.values 


scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
# 数据转为监督学习数据，time-step=1
reframed = series_to_supervised(scaled, 1, 1)

# 去掉不想预测的列
reframed.drop(reframed.columns[[8,9,10,11,12,13]], axis=1, inplace=True)
print(reframed.head())
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1   0.636816   0.295738   0.337945   0.631157        0.0   0.011366
# 2   0.545045   0.103358   0.335501   0.541487        0.0   0.144652
# 3   0.509006   0.110073   0.283802   0.502152        0.0   0.030869
# 4   0.488550   0.096987   0.315987   0.481110        0.0   0.000000
# 5   0.455597   0.099010   0.434417   0.449904        0.0   0.008973
#
#    var7(t-1)   var1(t)
# 1   0.782418  0.545045
# 2   0.782676  0.509006
# 3   0.774169  0.488550
# 4   0.778809  0.455597
# 5   0.798917  0.322555

# %% [markdown]
# ### * 上面我在小时内显示了7个输入变量（输入系列）和“Global_Active_Power”的1个输出变量

# %% [markdown]
# # 将其余数据拆分为训练集和验证集

# %% [markdown]
# ### * 首先，我将准备好的数据集拆分为训练集和测试集。为了加快模型的训练（为了演示），我们只会在第一年的数据上训练模型，然后在接下来的三年的数据上评估它

# %%
# 划分数据集
values = reframed.values

n_train_time = 365*24#以一年数据训练
train = values[:n_train_time, :]
test = values[n_train_time:, :]
##test = values[n_train_time:n_test_time, :]
# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
# 构建数据的3D 格式，即[samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape) 
#
# Out:
# (8760, 1, 7) (8760,) (25828, 1, 7) (25828,)

# %% [markdown]
# # 构建CNN-LSTM模型
#
# ### 1)  CNN 卷积个数10
# ### 2）LSTM 隐藏层单元为100
# ### 3) dropout 20%
# ### 4) 1个神经元在输出层中，用于预测Global_Active_Power。
# ### 5) 输入形状为1个时间步长，有7个特征
#
# ### 6)使用了平均绝对误差（MAE）损失函数和随机梯度下降的有效Adam。
# ### 7)  epochs=2, batch size = 70.

# %%
model = Sequential()
model.add(Conv1D(filters=10,kernel_size=1, padding='same', strides=1, activation='relu',input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(MaxPooling1D(pool_size=1))
model.add(Flatten())
model.add(RepeatVector(30))
model.add(LSTM(100))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')



# fit network
history = model.fit(train_X, train_y, epochs=20, batch_size=70, validation_data=(test_X, test_y), verbose=2, shuffle=False)

# 显示训练的loss值情况
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# 做预测
yhat = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], 7))
# i反归一化预测值
inv_yhat = np.concatenate((yhat, test_X[:, -6:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# 反归一化真实值
test_y = test_y.reshape((len(test_y), 1))
inv_y = np.concatenate((test_y, test_X[:, -6:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]
# 计算 RMSE
rmse = np.sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# Train on 8760 samples, validate on 25828 samples
# Epoch 1/20
#  - 4s - loss: 0.0165 - val_loss: 0.0086
# Epoch 2/20
#  - 4s - loss: 0.0109 - val_loss: 0.0085
# Epoch 3/20
#  - 5s - loss: 0.0107 - val_loss: 0.0087
# Epoch 4/20
#  - 5s - loss: 0.0105 - val_loss: 0.0088
# Epoch 5/20
#  - 5s - loss: 0.0105 - val_loss: 0.0086
# Epoch 6/20
#  - 5s - loss: 0.0105 - val_loss: 0.0088
# Epoch 7/20
#  - 5s - loss: 0.0103 - val_loss: 0.0087
# Epoch 8/20
#  - 5s - loss: 0.0104 - val_loss: 0.0088
# Epoch 9/20
#  - 5s - loss: 0.0104 - val_loss: 0.0086
# Epoch 10/20
#  - 5s - loss: 0.0103 - val_loss: 0.0087
# Epoch 11/20
#  - 5s - loss: 0.0103 - val_loss: 0.0087
# Epoch 12/20
#  - 5s - loss: 0.0103 - val_loss: 0.0086
# Epoch 13/20
#  - 5s - loss: 0.0103 - val_loss: 0.0086
# Epoch 14/20
#  - 5s - loss: 0.0102 - val_loss: 0.0086
# Epoch 15/20
#  - 5s - loss: 0.0102 - val_loss: 0.0087
# Epoch 16/20
#  - 5s - loss: 0.0102 - val_loss: 0.0087
# Epoch 17/20
#  - 5s - loss: 0.0101 - val_loss: 0.0088
# ...

# %% [markdown]
# ### 请注意，为了改进模型，必须调整epoch和Batch_size等超参数

# %%
## 时间步长，每个步长为一小时（您可以轻松地将时间步长转换为实际时间索引）
## 为了演示，我只比较了200小时内的预测. 
#显示预测结果
aa=[x for x in range(200)]
plt.plot(aa, inv_y[:200], marker='.', label="actual")
plt.plot(aa, inv_yhat[:200], 'r', label="prediction")
plt.ylabel('Global_active_power', size=15)
plt.xlabel('Time step', size=15)
plt.legend(fontsize=15)
plt.show()

# %% [markdown]
# # 结束语

# %% [markdown]
# ### * 为了减少计算时间，并快速得到一些结果，我用第一年的数据（在一小时内重新采样）来训练模型，并用剩余的数据来测试模型。
#
# ### * 此外，我设计的神经网络架构是一个玩具模型。通过添加CNN和退出层，可以很容易地对其进行改进。CNN在这里很有用，因为数据中存在相关性（CNN层是探测数据局部结构的好方法）

# %%
## 结束语
##店铺其他算法
